# %% [markdown]
# <a href="https://colab.research.google.com/github/Sebasangel10/Extraccion_de_datos/blob/main/extraccion_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importamos librerias requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfb= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
dfb

# %%
filtro1=dfb[dfb["NOMBRE_VENDEDOR"]== "DIEGO ARMANDO LEON DURAN"]
filtro1

# %%
filtro1.to_csv("Filtro1.csv")

# %%
filtro2= dfb.iloc[2:25,: ]
filtro2

# %%
filtro1.to_csv("Filtro2.csv")

# %%
filtro3=dfb.iloc[ : ,[1,3,7]]
filtro3

# %%
filtro3.to_csv("Filtro3.csv")

# %%
dfb1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx',index_col=3)
dfb1
# Out:
#                              CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# NOMBRE_CLIENTE
# PÚBLICO EN GENERAL            F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# JUAN ANTONIO RESENDIZ UGALDE  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ANA BARBARA CRUZ PALACIOS     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# OMAR RODRIGUEZ GOMEZ          F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# PÚBLICO EN GENERAL            F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...                              ...        ...                        ...
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# SEVEN DAYS ALL SPORT          F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# REVUELTA MONTECARLO           F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# CPEG SOLUTIONS                F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                               CANT       CVE_ART  \
# ...

# %%
filtro4=dfb1.loc[["SEVEN DAYS ALL SPORT","PÚBLICO EN GENERAL"], ["PRECIO_UNITARIO"]]
filtro4
# Out:
#                       PRECIO_UNITARIO
# NOMBRE_CLIENTE
# SEVEN DAYS ALL SPORT          2182.35
# PÚBLICO EN GENERAL             434.48
# PÚBLICO EN GENERAL             172.41
# PÚBLICO EN GENERAL             237.07
# PÚBLICO EN GENERAL             605.00
# ...                               ...
# PÚBLICO EN GENERAL             576.65
# PÚBLICO EN GENERAL             689.63
# PÚBLICO EN GENERAL            3416.00
# PÚBLICO EN GENERAL             410.00
# PÚBLICO EN GENERAL             732.00
#
# [95 rows x 1 columns]

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("Filtro4.1.csv")

# %%
#Filtro por cabecera
filtro5=dfb1.head(10)
filtro5
#Convertir archivo filtrado a CSV
filtro5.to_csv("Filtro5.1.csv")

#Filtro por el final 
filtro6=dfb1.tail(5)
filtro6

#Convertir archivo filtrado a CSV
filtro6.to_csv("Filtro6.1.csv")

# %%
#Filtro por comparacion
filtro7=dfb1[dfb1["PRECIO_UNITARIO"] > 20000]
filtro7

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("Filtro7.1.csv")

# %%
#Filtro Y
filtro8=dfb1[(dfb1["PRECIO_UNITARIO"] < 6000) & (dfb1["FECHA_DOC"] == "2022-12-23")]
filtro8

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("Filtro8.1.csv")

# %%
#Filtro o
filtro9=df[(df["PRECIO_UNITARIO"] < 9000) | (df["FECHA_DOC"] == "2022-12-23")]
filtro9

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("Filtro9.1.csv")

# %%
#Filtro not
filtro10=df[~(df["PRECIO_UNITARIO"] >= 1000) & ~(df["FECHA_DOC"] == "2022-12-23")]
filtro10

# %%
#Convertir archivo filtrado a CSV
filtro10.to_csv("Filtro10.1.csv")
